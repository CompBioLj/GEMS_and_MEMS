# %% [markdown]
# https://www.pythonfordatascience.org/factorial-anova-python/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from itertools import permutations, product, combinations
from scipy.stats import pearsonr, spearmanr

from itertools import permutations

# %%
#https://www.scribbr.com/statistics/two-way-anova/
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multitest as multi

# %%
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning, HessianInversionWarning, ValueWarning
# ignore these warning
warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=HessianInversionWarning)
warnings.filterwarnings("ignore", category=ValueWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %% [markdown]
# ## Settings

# %%
analysis = "Fastcore"
#analysis = "iMAT"

#analysis = "gimme"
#analysis = "init"
#analysis = "tinit"

# %%
analysis_type = "FVA"
#analysis_type = "pFBA"

# %% [markdown]
# ### Sum of squares type

# %%
ss_type = 3

if ss_type == 3:
    formula = "activity ~ C(gender, Sum) + C(genotype, Sum) + C(diet, Sum) + C(gender, Sum)*C(genotype, Sum) + C(gender, Sum)*C(diet, Sum) + C(genotype, Sum)*C(diet, Sum) + C(gender, Sum)*C(genotype, Sum)*C(diet, Sum)"
    #formula = "activity ~ C(gender, Sum) + C(genotype, Sum) + C(diet, Sum)"
else:
    formula = "activity ~ C(gender) + C(genotype) + C(diet) + C(gender)*C(genotype) + C(gender)*C(diet) + C(genotype)*C(diet) + C(gender)*C(genotype)*C(diet)"

# %% [markdown]
# ### Number of reactions to observe
# Only keep the first `n_reactions` reactions (unless set to zero)

# %%
n_reactions = 0 # all reactions will be included
#n_reactions = 10

# %% [markdown]
# ## Read the data

# %%
df = pd.read_csv("data\\"+analysis_type+"_"+analysis+".csv", sep=";")

# %%
models = list(df.columns[1:])
#models = list(map(lambda x: x.split("_")[1].split(".")[0], models))

# %%
df.columns = [df.columns[0]] + models

# %% [markdown]
# #### Convert values to float and replace nans with zeros

# %%
df[models] = df[models].astype(float)
df = df.fillna(0)

# %% [markdown]
# ### Filter the reactions

# %% [markdown]
# #### Remove the reactions that are always the same

# %%
#df[models].eq(df[models].iloc[:, 0], axis=0).all(axis=1)

# %%
df = df[~df[models].eq(df[models].iloc[:, 0], axis=0).all(axis=1)]

# %%
#df = df.loc[~(df[df.columns[1:]]==0).all(axis=1)]
#df = df.loc[~(df[df.columns[1:]]==1).all(axis=1)]

# %%
df.shape
# Out:
# (5789, 37)

# %% [markdown]
# #### If `n_reactions` is not zero only retain first `n_reactions`

# %%
if n_reactions:
    df = df.head(n_reactions)

# %% [markdown]
# # Groups

# %% [markdown]
# ## Grouping by genotype

# %%
# WT
genotype0 = ["GSM1405493","GSM1405505","GSM1405517", 
              "GSM1405489","GSM1405501","GSM1405513",
              "GSM1405485","GSM1405497","GSM1405509",
              "GSM1405494","GSM1405506","GSM1405518",
              "GSM1405490","GSM1405502","GSM1405514",
              "GSM1405486","GSM1405498","GSM1405510"]
# KO
genotype1 = ["GSM1405495","GSM1405507","GSM1405519",
              "GSM1405491","GSM1405503","GSM1405515",
              "GSM1405487","GSM1405499","GSM1405511",
              "GSM1405496","GSM1405508","GSM1405520",
              "GSM1405492","GSM1405504","GSM1405516",
              "GSM1405488","GSM1405500","GSM1405512"]
genotype = (genotype0, genotype1)

# %% [markdown]
# ## Grouping by diet

# %%
# LFnC
diet0 = ["GSM1405485","GSM1405497","GSM1405509","GSM1405487","GSM1405499","GSM1405511",
         "GSM1405486","GSM1405498","GSM1405510","GSM1405488","GSM1405500","GSM1405512"]

# HFnC
diet1 = ["GSM1405489","GSM1405501","GSM1405513","GSM1405491","GSM1405503","GSM1405515",
         "GSM1405490","GSM1405502","GSM1405514","GSM1405492","GSM1405504","GSM1405516"]

# HFC
diet2 = ["GSM1405493","GSM1405505","GSM1405517","GSM1405495","GSM1405507","GSM1405519",
         "GSM1405494","GSM1405506","GSM1405518","GSM1405496","GSM1405508","GSM1405520"]

diet = (diet0, diet1, diet2)

# %% [markdown]
# ## Grouping by gender

# %%
# F
gender0 = ["GSM1405493","GSM1405505","GSM1405517",
           "GSM1405489","GSM1405501","GSM1405513",
           "GSM1405485","GSM1405497","GSM1405509",
           "GSM1405495","GSM1405507","GSM1405519",
           "GSM1405491","GSM1405503","GSM1405515",
           "GSM1405487","GSM1405499","GSM1405511"]

# M
gender1 = ["GSM1405494","GSM1405506","GSM1405518",
           "GSM1405490","GSM1405502","GSM1405514",
           "GSM1405486","GSM1405498","GSM1405510",
           "GSM1405496","GSM1405508","GSM1405520",
           "GSM1405492","GSM1405504","GSM1405516",
           "GSM1405488","GSM1405500","GSM1405512"]

gender = (gender0, gender1)

# %% [markdown]
# ## Groups

# %%
groups = {"genotype": genotype, "diet": diet, "gender": gender}
labels = {"genotype": ("WT","KO"), "diet": ("LFnC", "HFnC", "HFC"), "gender": ("F","M")}

# %% [markdown]
# ## Retain only observed models

# %%
observed = gender0 + gender1

# %%
df = df[[df.columns[0]] + observed]

# %%
df.shape
# Out:
# (5789, 37)

# %% [markdown]
# # Organize the data

# %%
df2 = pd.melt(df, id_vars=["rxns"])
df2.columns = ['rxn', 'model', 'activity']

# already did this
## convert activities to float
#df2['activity'] = df2['activity'].str.replace(",",".")
#df2['activity'] = df2['activity'].astype(float)

## replace nans with zero
#df2['activity'] = df2['activity'].fillna(0)

# %%
for i,factor in enumerate(gender):
    df2.loc[df2['model'].isin(factor), 'gender'] = "group " + str(i)
    
for i,factor in enumerate(genotype):
    df2.loc[df2['model'].isin(factor), 'genotype'] = "group " + str(i)

for i,factor in enumerate(diet):
    df2.loc[df2['model'].isin(factor), 'diet'] = "group " + str(i)

# %%
rxns = df2.rxn.unique()
len(rxns)
# Out:
# 5789

# %% [markdown]
# ## Basic test

# %%
#test run
data = df2[df2.rxn == rxns[0]]
model = ols(formula, data=data).fit()
aov_table = sm.stats.anova_lm(model, typ=ss_type)
Fs = aov_table['F'].values[1:-1]
Ps = aov_table['PR(>F)'].values[1:-1]

categories = list(aov_table['PR(>F)'].index[1:-1])
categories
# Out:
# ['C(gender, Sum)',
#  'C(genotype, Sum)',
#  'C(diet, Sum)',
#  'C(gender, Sum):C(genotype, Sum)',
#  'C(gender, Sum):C(diet, Sum)',
#  'C(genotype, Sum):C(diet, Sum)',
#  'C(gender, Sum):C(genotype, Sum):C(diet, Sum)']

# %%
aov_table
# Out:
#                                                      sum_sq    df  \
# Intercept                                     222993.828036   1.0
# C(gender, Sum)                                   771.604886   1.0
# C(genotype, Sum)                                 771.604886   1.0
# C(diet, Sum)                                    1543.209771   2.0
# C(gender, Sum):C(genotype, Sum)                  771.604886   1.0
# C(gender, Sum):C(diet, Sum)                     1543.209771   2.0
# C(genotype, Sum):C(diet, Sum)                   1543.209771   2.0
# C(gender, Sum):C(genotype, Sum):C(diet, Sum)    1543.209771   2.0
# Residual                                        4629.629314  24.0
#
#                                                         F        PR(>F)
# Intercept                                     1156.000083  8.154141e-22
# C(gender, Sum)                                   4.000000  5.693985e-02
# C(genotype, Sum)                                 4.000000  5.693985e-02
# C(diet, Sum)                                     4.000000  3.167635e-02
# C(gender, Sum):C(genotype, Sum)                  4.000000  5.693985e-02
# C(gender, Sum):C(diet, Sum)                      4.000000  3.167635e-02
# C(genotype, Sum):C(diet, Sum)                    4.000000  3.167635e-02
# C(gender, Sum):C(genotype, Sum):C(diet, Sum)     4.000000  3.167635e-02
# Residual                                              NaN           NaN

# %%
F_obt = np.zeros((len(rxns), len(Fs)))
P_obt = np.zeros((len(rxns), len(Ps)))

# %%
for i, rxn in enumerate(rxns):
    data = df2[df2.rxn == rxn]
    model = ols(formula, data=data).fit()
    aov_table = sm.stats.anova_lm(model, typ=ss_type)
    Fs = aov_table['F'].values[1:-1]
    Ps = aov_table['PR(>F)'].values[1:-1]    
    
    F_obt[i,:] = Fs
    P_obt[i,:] = Ps
    
    if i%100 == 0:
        print(str(i)+"/"+str(len(rxns)))
# Out:
# 0/5789
# 100/5789
# 200/5789
# 300/5789
# 400/5789
# 500/5789
# 600/5789
# 700/5789
# 800/5789
# 900/5789
# 1000/5789
# 1100/5789
# 1200/5789
# 1300/5789
# 1400/5789
# 1500/5789
# 1600/5789
# 1700/5789
# 1800/5789
# 1900/5789
# 2000/5789
# 2100/5789
# 2200/5789
# 2300/5789
# 2400/5789
# 2500/5789
# 2600/5789
# 2700/5789
# 2800/5789
# 2900/5789
# 3000/5789
# 3100/5789
# 3200/5789
# 3300/5789
# 3400/5789
# 3500/5789
# 3600/5789
# 3700/5789
# 3800/5789
# 3900/5789
# 4000/5789
# 4100/5789
# 4200/5789
# 4300/5789
# 4400/5789
# 4500/5789
# 4600/5789
# 4700/5789
# 4800/5789
# 4900/5789
# 5000/5789
# 5100/5789
# 5200/5789
# 5300/5789
# 5400/5789
# 5500/5789
# 5600/5789
# 5700/5789

# %% [markdown]
# ### Output of the basic test

# %%
df_res = pd.DataFrame(P_obt)
df_res.columns = categories
df_res['rxn'] = rxns
df_res = df_res[[df_res.columns[-1]]+list(df_res.columns[:-1])]

# %%
df_res
# Out:
#                   rxn  C(gender, Sum)  C(genotype, Sum)  C(diet, Sum)  \
# 0        10FTHF7GLUtl        0.056940          0.056940      0.031676
# 1        10FTHF7GLUtm        0.056940          0.056940      0.031676
# 2            10FTHFtl        0.056940          0.056940      0.031676
# 3         11DOCRTSLte        0.003272          0.115523      0.522669
# 4         11DOCRTSLtm        0.011994          0.007556      0.568011
# 5       11DOCRTSTRNte        0.045822          0.045822      0.039274
# 5779                       0.112157
# 5780                       0.031676
# 5781                       0.340598
# 5782                       0.031676
# 5783                       0.258702
# 5784                       0.068719
# 5785                       0.031676
# 5786                       0.340598
# 5787                       0.031676
# 5788                       0.006988
#
#       C(gender, Sum):C(genotype, Sum):C(diet, Sum)
# 0                                         0.031676
# 1                                         0.031676
# 2                                         0.031676
# 3                                         0.522669
# 4                                         0.488101
# 5                                         0.039274
# 6                                         0.719796
# 7                                         0.031676
# 8                                         0.031676
# 9                                         0.031676
# 10                                        0.031676
# 11                                        0.031676
# 12                                        0.031676
# 13                                        0.031676
# 14                                        0.031676
# 15                                        0.377777
# 16                                        0.031676
# 17                                        0.031676
# 18                                        0.031676
# 19                                        0.031676
# 20                                        0.382697
# 21                                        0.195228
# 22                                        0.031676
# 23                                        0.031676
# 24                                        0.031676
# 25                                        0.031676
# 26                                        0.031676
# 27                                        0.031676
# 28                                        0.031676
# 29                                        0.031676
# ...                                            ...
# 5759                                      0.814368
# 5760                                      0.031676
# 5761                                      0.382697
# 5762                                      0.031676
# 5763                                      0.031676
# 5764                                      0.031676
# 5765                                      0.031676
# 5766                                      0.031676
# 5767                                      0.031676
# 5768                                      0.031676
# 5769                                      0.031676
# 5770                                      0.031676
# 5771                                      0.031676
# 5772                                      0.031676
# 5773                                      0.031676
# 5774                                      0.612710
# 5775                                      0.258907
# 5776                                      0.678326
# 5777                                      0.460951
# 5778                                      0.460951
# 5779                                      0.460951
# 5780                                      0.031676
# 5781                                      0.002741
# 5782                                      0.031676
# 5783                                      0.120725
# 5784                                      0.068719
# 5785                                      0.031676
# 5786                                      0.002741
# 5787                                      0.031676
# 5788                                      0.050443
#
# [5789 rows x 8 columns]

# %% [markdown]
# ### Basic ANOVA format the results

# %%
df_res.columns = list(map(lambda x: x.replace(", Sum","").replace("):C(",",").replace("C(","p("), df_res.columns))

# %% [markdown]
# ### Basic ANOVA FDR

# %%
df_resq = df_res.copy()
for c in df_resq.columns[1:]:
    df_resq[c] = multi.multipletests(df_resq[c], method = 'fdr_bh')[1]
df_resq.columns = list(map(lambda x: x.replace("p(","q("), df_res.columns))

# %% [markdown]
# ### Save the results

# %%
df_res.to_csv("results_ANOVA\\"+analysis_type+"_"+analysis+"_basic_p.csv", index=False)
df_resq.to_csv("results_ANOVA\\"+analysis_type+"_"+analysis+"_basic_q.csv", index=False)

# %% [markdown]
# # Randomization test

# %%
N = 10000
C_F = np.zeros((len(rxns), len(Fs)))
observed = np.array(observed)

# %%
df_test = df2.copy()

# %%
for n in range(N):
    # generate permutations
    samp = np.random.permutation(range(len(observed)))
    gender_test = np.array((samp[:len(gender0)], samp[len(gender0):]))
    gender_test = observed[gender_test]

    samp = np.random.permutation(range(len(observed)))
    genotype_test = np.array((samp[:len(genotype0)], samp[len(genotype0):]))
    genotype_test = observed[genotype_test]

    samp = np.random.permutation(range(len(observed)))
    diet_test = np.array((samp[:len(diet0)], samp[len(diet0):len(diet0)+len(diet1)], samp[len(diet0)+len(diet1):]))
    diet_test = observed[diet_test]

    # prepare the dataframe with permuted factors
    for i,factor in enumerate(gender_test):
        df_test.loc[df_test['model'].isin(factor), 'gender'] = i

    for i,factor in enumerate(genotype_test):
        df_test.loc[df_test['model'].isin(factor), 'genotype'] = i

    for i,factor in enumerate(diet_test):
        df_test.loc[df_test['model'].isin(factor), 'diet'] = i  
    
    F_test = np.zeros((len(rxns), len(Fs)))
    
    # go through all the reactions and assess their F values
    for i, rxn in enumerate(rxns):
        data = df_test[df_test.rxn == rxn]
        model = ols(formula, data=data).fit()
        aov_table = sm.stats.anova_lm(model, typ=ss_type)
        Fs = aov_table['F'].values[1:-1]
        

        F_test[i,:] = Fs

        if i%100 == 0:
            print(str(n)+"/"+str(N)+"; "+str(i)+"/"+str(len(rxns)))
    
    C_F[F_obt > F_test] += 1
# Out:
# 0/1000; 0/10
# 1/1000; 0/10
# 2/1000; 0/10
# 3/1000; 0/10
# 4/1000; 0/10
# 5/1000; 0/10
# 6/1000; 0/10
# 7/1000; 0/10
# 8/1000; 0/10
# 9/1000; 0/10
# 10/1000; 0/10
# 11/1000; 0/10
# 12/1000; 0/10
# 13/1000; 0/10
# 14/1000; 0/10
# 15/1000; 0/10
# 16/1000; 0/10
# 17/1000; 0/10
# 18/1000; 0/10
# 19/1000; 0/10
# 20/1000; 0/10
# 21/1000; 0/10
# 22/1000; 0/10
# 23/1000; 0/10
# 24/1000; 0/10
# 25/1000; 0/10
# 26/1000; 0/10
# 27/1000; 0/10
# 28/1000; 0/10
# 29/1000; 0/10
# 30/1000; 0/10
# 31/1000; 0/10
# 32/1000; 0/10
# 33/1000; 0/10
# 34/1000; 0/10
# 35/1000; 0/10
# 36/1000; 0/10
# 37/1000; 0/10
# 38/1000; 0/10
# 39/1000; 0/10
# 40/1000; 0/10
# 41/1000; 0/10
# 42/1000; 0/10
# 43/1000; 0/10
# 44/1000; 0/10
# 45/1000; 0/10
# 46/1000; 0/10
# 47/1000; 0/10
# 48/1000; 0/10
# 49/1000; 0/10
# 50/1000; 0/10
# 51/1000; 0/10
# 52/1000; 0/10
# 53/1000; 0/10
# 54/1000; 0/10
# 55/1000; 0/10
# 56/1000; 0/10
# 57/1000; 0/10
# 58/1000; 0/10
# 59/1000; 0/10
# 60/1000; 0/10
# 61/1000; 0/10
# 62/1000; 0/10
# 63/1000; 0/10
# 64/1000; 0/10
# 65/1000; 0/10
# 66/1000; 0/10
# 67/1000; 0/10
# 68/1000; 0/10
# 69/1000; 0/10
# 70/1000; 0/10
# 71/1000; 0/10
# 72/1000; 0/10
# 73/1000; 0/10
# 74/1000; 0/10
# 75/1000; 0/10
# 76/1000; 0/10
# 77/1000; 0/10
# 78/1000; 0/10
# 79/1000; 0/10
# 80/1000; 0/10
# 81/1000; 0/10
# 82/1000; 0/10
# 83/1000; 0/10
# 84/1000; 0/10
# 85/1000; 0/10
# 86/1000; 0/10
# 87/1000; 0/10
# 88/1000; 0/10
# 89/1000; 0/10
# 90/1000; 0/10
# 91/1000; 0/10
# 92/1000; 0/10
# 93/1000; 0/10
# 94/1000; 0/10
# 95/1000; 0/10
# 96/1000; 0/10
# 97/1000; 0/10
# 98/1000; 0/10
# 99/1000; 0/10
# 100/1000; 0/10
# 101/1000; 0/10
# 102/1000; 0/10
# 103/1000; 0/10
# 104/1000; 0/10
# 105/1000; 0/10
# 106/1000; 0/10
# 107/1000; 0/10
# 108/1000; 0/10
# 109/1000; 0/10
# 110/1000; 0/10
# 111/1000; 0/10
# 112/1000; 0/10
# 113/1000; 0/10
# 114/1000; 0/10
# 115/1000; 0/10
# 116/1000; 0/10
# 117/1000; 0/10
# 118/1000; 0/10
# 119/1000; 0/10
# 120/1000; 0/10
# 121/1000; 0/10
# 122/1000; 0/10
# 123/1000; 0/10
# 124/1000; 0/10
# 125/1000; 0/10
# 126/1000; 0/10
# 127/1000; 0/10
# 128/1000; 0/10
# 129/1000; 0/10
# 130/1000; 0/10
# 131/1000; 0/10
# 132/1000; 0/10
# 133/1000; 0/10
# 134/1000; 0/10
# 135/1000; 0/10
# 136/1000; 0/10
# 137/1000; 0/10
# 138/1000; 0/10
# 139/1000; 0/10
# 140/1000; 0/10
# 141/1000; 0/10
# 142/1000; 0/10
# 143/1000; 0/10
# 144/1000; 0/10
# 145/1000; 0/10
# 146/1000; 0/10
# 147/1000; 0/10
# 148/1000; 0/10
# 149/1000; 0/10
# 150/1000; 0/10
# 151/1000; 0/10
# 152/1000; 0/10
# 153/1000; 0/10
# 154/1000; 0/10
# 155/1000; 0/10
# 156/1000; 0/10
# 157/1000; 0/10
# 158/1000; 0/10
# 159/1000; 0/10
# 160/1000; 0/10
# 161/1000; 0/10
# 162/1000; 0/10
# 163/1000; 0/10
# 164/1000; 0/10
# 165/1000; 0/10
# 166/1000; 0/10
# 167/1000; 0/10
# 168/1000; 0/10
# 169/1000; 0/10
# 170/1000; 0/10
# 171/1000; 0/10
# 172/1000; 0/10
# 173/1000; 0/10
# 174/1000; 0/10
# 175/1000; 0/10
# 176/1000; 0/10
# 177/1000; 0/10
# 178/1000; 0/10
# 179/1000; 0/10
# 180/1000; 0/10
# 181/1000; 0/10
# 182/1000; 0/10
# 183/1000; 0/10
# 184/1000; 0/10
# 185/1000; 0/10
# 186/1000; 0/10
# 187/1000; 0/10
# 188/1000; 0/10
# 189/1000; 0/10
# 190/1000; 0/10
# 191/1000; 0/10
# 192/1000; 0/10
# 193/1000; 0/10
# 194/1000; 0/10
# 195/1000; 0/10
# 196/1000; 0/10
# 197/1000; 0/10
# 198/1000; 0/10
# 199/1000; 0/10
# 200/1000; 0/10
# 201/1000; 0/10
# 202/1000; 0/10
# 203/1000; 0/10
# 204/1000; 0/10
# 205/1000; 0/10
# 206/1000; 0/10
# 207/1000; 0/10
# 208/1000; 0/10
# 209/1000; 0/10
# 210/1000; 0/10
# 211/1000; 0/10
# 212/1000; 0/10
# 213/1000; 0/10
# 214/1000; 0/10
# 215/1000; 0/10
# 216/1000; 0/10
# 217/1000; 0/10
# 218/1000; 0/10
# 219/1000; 0/10
# 220/1000; 0/10
# 221/1000; 0/10
# 222/1000; 0/10
# 223/1000; 0/10
# 224/1000; 0/10
# 225/1000; 0/10
# 226/1000; 0/10
# 227/1000; 0/10
# 228/1000; 0/10
# 229/1000; 0/10
# 230/1000; 0/10
# 231/1000; 0/10
# 232/1000; 0/10
# 497/1000; 0/10
# 498/1000; 0/10
# 499/1000; 0/10
# 500/1000; 0/10
# 501/1000; 0/10
# 502/1000; 0/10
# 503/1000; 0/10
# 504/1000; 0/10
# 505/1000; 0/10
# 506/1000; 0/10
# 507/1000; 0/10
# 508/1000; 0/10
# 509/1000; 0/10
# 510/1000; 0/10
# 511/1000; 0/10
# 512/1000; 0/10
# 513/1000; 0/10
# 514/1000; 0/10
# 515/1000; 0/10
# 516/1000; 0/10
# 517/1000; 0/10
# 518/1000; 0/10
# 519/1000; 0/10
# 520/1000; 0/10
# 521/1000; 0/10
# 522/1000; 0/10
# 523/1000; 0/10
# 524/1000; 0/10
# 525/1000; 0/10
# 526/1000; 0/10
# 527/1000; 0/10
# 528/1000; 0/10
# 529/1000; 0/10
# 530/1000; 0/10
# 531/1000; 0/10
# 532/1000; 0/10
# 533/1000; 0/10
# 534/1000; 0/10
# 535/1000; 0/10
# 536/1000; 0/10
# 537/1000; 0/10
# 538/1000; 0/10
# 539/1000; 0/10
# 540/1000; 0/10
# 541/1000; 0/10
# 542/1000; 0/10
# 543/1000; 0/10
# 544/1000; 0/10
# 545/1000; 0/10
# 546/1000; 0/10
# 547/1000; 0/10
# 548/1000; 0/10
# 549/1000; 0/10
# 550/1000; 0/10
# 551/1000; 0/10
# 552/1000; 0/10
# 553/1000; 0/10
# 554/1000; 0/10
# 555/1000; 0/10
# 556/1000; 0/10
# 557/1000; 0/10
# 558/1000; 0/10
# 559/1000; 0/10
# 560/1000; 0/10
# 561/1000; 0/10
# 562/1000; 0/10
# 563/1000; 0/10
# 564/1000; 0/10
# 565/1000; 0/10
# 566/1000; 0/10
# 567/1000; 0/10
# 568/1000; 0/10
# 569/1000; 0/10
# 570/1000; 0/10
# 571/1000; 0/10
# 572/1000; 0/10
# 573/1000; 0/10
# 574/1000; 0/10
# 575/1000; 0/10
# 576/1000; 0/10
# 577/1000; 0/10
# 578/1000; 0/10
# 579/1000; 0/10
# 580/1000; 0/10
# 581/1000; 0/10
# 582/1000; 0/10
# 583/1000; 0/10
# 584/1000; 0/10
# 585/1000; 0/10
# 586/1000; 0/10
# 587/1000; 0/10
# 588/1000; 0/10
# 589/1000; 0/10
# 590/1000; 0/10
# 591/1000; 0/10
# 592/1000; 0/10
# 593/1000; 0/10
# 594/1000; 0/10
# 595/1000; 0/10
# 596/1000; 0/10
# 597/1000; 0/10
# 598/1000; 0/10
# 599/1000; 0/10
# 600/1000; 0/10
# 601/1000; 0/10
# 602/1000; 0/10
# 603/1000; 0/10
# 604/1000; 0/10
# 605/1000; 0/10
# 606/1000; 0/10
# 607/1000; 0/10
# 608/1000; 0/10
# 609/1000; 0/10
# 610/1000; 0/10
# 611/1000; 0/10
# 612/1000; 0/10
# 613/1000; 0/10
# 614/1000; 0/10
# 615/1000; 0/10
# 616/1000; 0/10
# 617/1000; 0/10
# 618/1000; 0/10
# 619/1000; 0/10
# 620/1000; 0/10
# 621/1000; 0/10
# 622/1000; 0/10
# 623/1000; 0/10
# 624/1000; 0/10
# 625/1000; 0/10
# 626/1000; 0/10
# 627/1000; 0/10
# 628/1000; 0/10
# 629/1000; 0/10
# 630/1000; 0/10
# 631/1000; 0/10
# 632/1000; 0/10
# 633/1000; 0/10
# 634/1000; 0/10
# 635/1000; 0/10
# 636/1000; 0/10
# 637/1000; 0/10
# 638/1000; 0/10
# 639/1000; 0/10
# 640/1000; 0/10
# 641/1000; 0/10
# 642/1000; 0/10
# 643/1000; 0/10
# 644/1000; 0/10
# 645/1000; 0/10
# 646/1000; 0/10
# 647/1000; 0/10
# 648/1000; 0/10
# 649/1000; 0/10
# 650/1000; 0/10
# 651/1000; 0/10
# 652/1000; 0/10
# 653/1000; 0/10
# 654/1000; 0/10
# 655/1000; 0/10
# 656/1000; 0/10
# 657/1000; 0/10
# 658/1000; 0/10
# 659/1000; 0/10
# 660/1000; 0/10
# 661/1000; 0/10
# 662/1000; 0/10
# 663/1000; 0/10
# 664/1000; 0/10
# 665/1000; 0/10
# 666/1000; 0/10
# 667/1000; 0/10
# 668/1000; 0/10
# 669/1000; 0/10
# 670/1000; 0/10
# 671/1000; 0/10
# 672/1000; 0/10
# 673/1000; 0/10
# 674/1000; 0/10
# 675/1000; 0/10
# 676/1000; 0/10
# 677/1000; 0/10
# 678/1000; 0/10
# 679/1000; 0/10
# 680/1000; 0/10
# 681/1000; 0/10
# 682/1000; 0/10
# 683/1000; 0/10
# 684/1000; 0/10
# 685/1000; 0/10
# 686/1000; 0/10
# 687/1000; 0/10
# 688/1000; 0/10
# 689/1000; 0/10
# 690/1000; 0/10
# 691/1000; 0/10
# 692/1000; 0/10
# 693/1000; 0/10
# 694/1000; 0/10
# 695/1000; 0/10
# 696/1000; 0/10
# 697/1000; 0/10
# 698/1000; 0/10
# 699/1000; 0/10
# 700/1000; 0/10
# 701/1000; 0/10
# 702/1000; 0/10
# 703/1000; 0/10
# 704/1000; 0/10
# 705/1000; 0/10
# 706/1000; 0/10
# 707/1000; 0/10
# 708/1000; 0/10
# 709/1000; 0/10
# 710/1000; 0/10
# 711/1000; 0/10
# 712/1000; 0/10
# 713/1000; 0/10
# 714/1000; 0/10
# 715/1000; 0/10
# 716/1000; 0/10
# 717/1000; 0/10
# 718/1000; 0/10
# 719/1000; 0/10
# 720/1000; 0/10
# 721/1000; 0/10
# 722/1000; 0/10
# 723/1000; 0/10
# 724/1000; 0/10
# 725/1000; 0/10
# 726/1000; 0/10
# 727/1000; 0/10
# 728/1000; 0/10
# 729/1000; 0/10
# 730/1000; 0/10
# 731/1000; 0/10
# 732/1000; 0/10
# 733/1000; 0/10
# 734/1000; 0/10
# 735/1000; 0/10
# 736/1000; 0/10
# 737/1000; 0/10
# 738/1000; 0/10
# 739/1000; 0/10
# 740/1000; 0/10
# 741/1000; 0/10
# 742/1000; 0/10
# 743/1000; 0/10
# 744/1000; 0/10
# 745/1000; 0/10
# 746/1000; 0/10
# 747/1000; 0/10
# 748/1000; 0/10
# 749/1000; 0/10
# 750/1000; 0/10
# 751/1000; 0/10
# 752/1000; 0/10
# 753/1000; 0/10
# 754/1000; 0/10
# 755/1000; 0/10
# 756/1000; 0/10
# 757/1000; 0/10
# 758/1000; 0/10
# 759/1000; 0/10
# 760/1000; 0/10
# 761/1000; 0/10
# 762/1000; 0/10
# 763/1000; 0/10
# 764/1000; 0/10
# 765/1000; 0/10
# 766/1000; 0/10
# 767/1000; 0/10
# 768/1000; 0/10
# 769/1000; 0/10
# 770/1000; 0/10
# 771/1000; 0/10
# 772/1000; 0/10
# 773/1000; 0/10
# 774/1000; 0/10
# 775/1000; 0/10
# 776/1000; 0/10
# 777/1000; 0/10
# 778/1000; 0/10
# 779/1000; 0/10
# 780/1000; 0/10
# 781/1000; 0/10
# 782/1000; 0/10
# 783/1000; 0/10
# 784/1000; 0/10
# 785/1000; 0/10
# 786/1000; 0/10
# 787/1000; 0/10
# 788/1000; 0/10
# 789/1000; 0/10
# 790/1000; 0/10
# 791/1000; 0/10
# 792/1000; 0/10
# 793/1000; 0/10
# 794/1000; 0/10
# 795/1000; 0/10
# 796/1000; 0/10
# 797/1000; 0/10
# 798/1000; 0/10
# 799/1000; 0/10
# 800/1000; 0/10
# 801/1000; 0/10
# 802/1000; 0/10
# 803/1000; 0/10
# 804/1000; 0/10
# 805/1000; 0/10
# 806/1000; 0/10
# 807/1000; 0/10
# 808/1000; 0/10
# 809/1000; 0/10
# 810/1000; 0/10
# 811/1000; 0/10
# 812/1000; 0/10
# 813/1000; 0/10
# 814/1000; 0/10
# 815/1000; 0/10
# 816/1000; 0/10
# 817/1000; 0/10
# 818/1000; 0/10
# 819/1000; 0/10
# 820/1000; 0/10
# 821/1000; 0/10
# 822/1000; 0/10
# 823/1000; 0/10
# 824/1000; 0/10
# 825/1000; 0/10
# 826/1000; 0/10
# 827/1000; 0/10
# 828/1000; 0/10
# 829/1000; 0/10
# 830/1000; 0/10
# 831/1000; 0/10
# 832/1000; 0/10
# 833/1000; 0/10
# 834/1000; 0/10
# 835/1000; 0/10
# 836/1000; 0/10
# 837/1000; 0/10
# 838/1000; 0/10
# 839/1000; 0/10
# 840/1000; 0/10
# 841/1000; 0/10
# 842/1000; 0/10
# 843/1000; 0/10
# 844/1000; 0/10
# 845/1000; 0/10
# 846/1000; 0/10
# 847/1000; 0/10
# 848/1000; 0/10
# 849/1000; 0/10
# 850/1000; 0/10
# 851/1000; 0/10
# 852/1000; 0/10
# 853/1000; 0/10
# 854/1000; 0/10
# 855/1000; 0/10
# 856/1000; 0/10
# 857/1000; 0/10
# 858/1000; 0/10
# 859/1000; 0/10
# 860/1000; 0/10
# 861/1000; 0/10
# 862/1000; 0/10
# 863/1000; 0/10
# 864/1000; 0/10
# 865/1000; 0/10
# 866/1000; 0/10
# 867/1000; 0/10
# 868/1000; 0/10
# 869/1000; 0/10
# 870/1000; 0/10
# 871/1000; 0/10
# 872/1000; 0/10
# 873/1000; 0/10
# 874/1000; 0/10
# 875/1000; 0/10
# 876/1000; 0/10
# 877/1000; 0/10
# 878/1000; 0/10
# 879/1000; 0/10
# 880/1000; 0/10
# 881/1000; 0/10
# 882/1000; 0/10
# 883/1000; 0/10
# 884/1000; 0/10
# 885/1000; 0/10
# 886/1000; 0/10
# 887/1000; 0/10
# 888/1000; 0/10
# 889/1000; 0/10
# 890/1000; 0/10
# 891/1000; 0/10
# 892/1000; 0/10
# 893/1000; 0/10
# 894/1000; 0/10
# 895/1000; 0/10
# 896/1000; 0/10
# 897/1000; 0/10
# 898/1000; 0/10
# 899/1000; 0/10
# 900/1000; 0/10
# 901/1000; 0/10
# 902/1000; 0/10
# 903/1000; 0/10
# 904/1000; 0/10
# 905/1000; 0/10
# 906/1000; 0/10
# 907/1000; 0/10
# 908/1000; 0/10
# 909/1000; 0/10
# 910/1000; 0/10
# 911/1000; 0/10
# 912/1000; 0/10
# 913/1000; 0/10
# 914/1000; 0/10
# 915/1000; 0/10
# 916/1000; 0/10
# 917/1000; 0/10
# 918/1000; 0/10
# 919/1000; 0/10
# 920/1000; 0/10
# 921/1000; 0/10
# 922/1000; 0/10
# 923/1000; 0/10
# 924/1000; 0/10
# 925/1000; 0/10
# 926/1000; 0/10
# 927/1000; 0/10
# 928/1000; 0/10
# 929/1000; 0/10
# 930/1000; 0/10
# 931/1000; 0/10
# 932/1000; 0/10
# 933/1000; 0/10
# 934/1000; 0/10
# 935/1000; 0/10
# 936/1000; 0/10
# 937/1000; 0/10
# 938/1000; 0/10
# 939/1000; 0/10
# 940/1000; 0/10
# 941/1000; 0/10
# 942/1000; 0/10
# 943/1000; 0/10
# 944/1000; 0/10
# 945/1000; 0/10
# 946/1000; 0/10
# 947/1000; 0/10
# 948/1000; 0/10
# 949/1000; 0/10
# 950/1000; 0/10
# 951/1000; 0/10
# 952/1000; 0/10
# 953/1000; 0/10
# 954/1000; 0/10
# 955/1000; 0/10
# 956/1000; 0/10
# 957/1000; 0/10
# 958/1000; 0/10
# 959/1000; 0/10
# 960/1000; 0/10
# 961/1000; 0/10
# 962/1000; 0/10
# 963/1000; 0/10
# 964/1000; 0/10
# 965/1000; 0/10
# 966/1000; 0/10
# 967/1000; 0/10
# 968/1000; 0/10
# 969/1000; 0/10
# 970/1000; 0/10
# 971/1000; 0/10
# 972/1000; 0/10
# 973/1000; 0/10
# 974/1000; 0/10
# 975/1000; 0/10
# 976/1000; 0/10
# 977/1000; 0/10
# 978/1000; 0/10
# 979/1000; 0/10
# 980/1000; 0/10
# 981/1000; 0/10
# 982/1000; 0/10
# 983/1000; 0/10
# 984/1000; 0/10
# 985/1000; 0/10
# 986/1000; 0/10
# 987/1000; 0/10
# 988/1000; 0/10
# 989/1000; 0/10
# 990/1000; 0/10
# 991/1000; 0/10
# 992/1000; 0/10
# 993/1000; 0/10
# 994/1000; 0/10
# 995/1000; 0/10
# 996/1000; 0/10
# 997/1000; 0/10
# 998/1000; 0/10
# 999/1000; 0/10

# %%
C_F
# Out:
# array([[750., 751., 750., 751., 750., 750., 751.],
#        [992., 980., 515., 912.,   1.,   0., 489.],
#        [990., 982., 530., 927.,   2.,   1., 505.],
#        [765., 765., 758., 766., 759., 758., 758.],
#        [980., 830., 766., 371., 964., 465., 767.],
#        [  4.,   0., 142., 988., 350., 361., 144.],
#        [955., 358., 531., 338., 935., 530., 529.],
#        [945., 954., 927., 958., 937., 941., 939.],
#        [818., 791., 438., 822., 416., 406., 418.],
#        [720., 921., 303., 297., 293., 967., 565.]])

# %% [markdown]
# ### Output of the randomization test

# %%
p_F = C_F / N
df_res2 = pd.DataFrame(p_F)
df_res2.columns = categories
df_res2['rxn'] = rxns
df_res2 = df_res2[[df_res2.columns[-1]]+list(df_res2.columns[:-1])]

# %% [markdown]
# ### Randomization test format the results

# %%
df_res2.columns = list(map(lambda x: x.replace(", Sum","").replace("):C(",",").replace("C(","p("), df_res2.columns))
df_res2
# Out:
#               rxn  p(gender)  p(genotype)  p(diet)  p(gender,genotype)  \
# 0        10FTHFtm      0.750        0.751    0.750               0.751
# 1     11DOCRTSLte      0.992        0.980    0.515               0.912
# 2     11DOCRTSLtm      0.990        0.982    0.530               0.927
# 3  17AHPRGNLONEte      0.765        0.765    0.758               0.766
# 4   17AHPRGSTRNte      0.980        0.830    0.766               0.371
# 5        2AMADPTm      0.004        0.000    0.142               0.988
# 6       2OXOADOXm      0.955        0.358    0.531               0.338
# 7        2OXOADPt      0.945        0.954    0.927               0.958
# 8         34HPLFM      0.818        0.791    0.438               0.822
# 9        35CGMPtn      0.720        0.921    0.303               0.297
#
#    p(gender,diet)  p(genotype,diet)  p(gender,genotype,diet)
# 0           0.750             0.750                    0.751
# 1           0.001             0.000                    0.489
# 2           0.002             0.001                    0.505
# 3           0.759             0.758                    0.758
# 4           0.964             0.465                    0.767
# 5           0.350             0.361                    0.144
# 6           0.935             0.530                    0.529
# 7           0.937             0.941                    0.939
# 8           0.416             0.406                    0.418
# 9           0.293             0.967                    0.565

# %% [markdown]
# ### Randomization test FDR

# %%
df_res2q = df_res2.copy()
for c in df_res2q.columns[1:]:
    df_res2q[c] = multi.multipletests(df_res2q[c], method = 'fdr_bh')[1]
df_res2q.columns = list(map(lambda x: x.replace("p(","q("), df_res2.columns))
df_res2q
# Out:
#               rxn  q(gender)  q(genotype)   q(diet)  q(gender,genotype)  \
# 0        10FTHFtm      0.992        0.982  0.851111               0.988
# 1     11DOCRTSLte      0.992        0.982  0.851111               0.988
# 2     11DOCRTSLtm      0.992        0.982  0.851111               0.988
# 3  17AHPRGNLONEte      0.992        0.982  0.851111               0.988
# 4   17AHPRGSTRNte      0.992        0.982  0.851111               0.988
# 5        2AMADPTm      0.040        0.000  0.851111               0.988
# 6       2OXOADOXm      0.992        0.982  0.851111               0.988
# 7        2OXOADPt      0.992        0.982  0.927000               0.988
# 8         34HPLFM      0.992        0.982  0.851111               0.988
# 9        35CGMPtn      0.992        0.982  0.851111               0.988
#
#    q(gender,diet)  q(genotype,diet)  q(gender,genotype,diet)
# 0           0.964          0.947500                 0.852222
# 1           0.010          0.000000                 0.852222
# 2           0.010          0.005000                 0.852222
# 3           0.964          0.947500                 0.852222
# 4           0.964          0.883333                 0.852222
# 5           0.832          0.883333                 0.852222
# 6           0.964          0.883333                 0.852222
# 7           0.964          0.967000                 0.939000
# 8           0.832          0.883333                 0.852222
# 9           0.832          0.967000                 0.852222

# %% [markdown]
# ### Save the results

# %%
df_res2.to_csv("results_ANOVA\\"+analysis_type+"_"+analysis+"_randomization_p.csv", index=False)
df_res2q.to_csv("results_ANOVA\\"+analysis_type+"_"+analysis+"_randomization_q.csv", index=False)
